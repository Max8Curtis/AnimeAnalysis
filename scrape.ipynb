# %% [markdown]
# # Main scraping file

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import re

# %%
BASE_URL = "https://myanimelist.net/"
TOP_X_URL = BASE_URL + "topanime.php?limit="
MAX_IDX = 13650

# %%
# Get information for these fields
columns = ['Synonyms', 'Title', 'Japanese', 'English', 'Type', 'Episodes', 'Status', 'Aired', 'Premiered', 'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source', 'Genres', 'Demographic', 'Duration', 'Rating', 'Score', 'Ranked', 'Popularity', 'Members', 'Favorites']
df = pd.DataFrame(columns=columns, index=None)

# %%
def get_page_urls(idx):
    url = TOP_X_URL + str(idx)

    url_list = []

    resp = requests.get(url)
    if resp.status_code == 200:
        soup = BeautifulSoup(resp.text, "html.parser")
        urls_found = soup.find_all("a", {"class": re.compile("^hoverinfo_trigger$")}) # Search for link to anime page

        url_list = [urls_found[x].attrs['href'] for x in range(0,len(urls_found), 2)] # BeautifulSoup returns each link twice (soup returns even when regex doesn't match), so take every second
        # print(url_list)
        return url_list
    else:
        return None
    
def get_page_info(url):
    record = {x : None for x in columns} # Store each page information in dict
    resp = requests.get(url)
    if resp.status_code == 200:
        soup = BeautifulSoup(resp.text, "html.parser")

        title_jp = soup.find("h1", {"class": "title-name h1_bold_none"}).text
        print(title_jp)

        record['Title'] = title_jp

        fields = []
        for x in soup.find_all("div", {"class": "spaceit_pad"}):
            
            if x.find("span") is None:
                break
            
            field = x.find("span").text.replace(":","")
            fields.append(field)
            if field == "Score":
                info = x.find("span", {"itemprop": "ratingValue"}).text
            elif field == "Ranked": # Ranked field is obtained from top bar, not side bar
                continue
            else:
                if x.find_all("a") != []:
                    info = [y.text.replace("\n", "").rstrip().lstrip() for y in x.find_all("a")]

                if x.find_all("a") == []:
                    info = x.text[x.text.index(":")+2:].replace("\n", "").rstrip().lstrip()

                if field == "Popularity":
                    info = info.replace("#", "")

                if field == "Members" or field == "Favorites":
                    if "," in info:
                        info = info.replace(",", "")
            
            record[field] = info

        field = 'Ranked'
        info = soup.find("span", {"class": "numbers ranked"}).find_next().text.replace("#", "") # Get rank from top of page instead of side bar

        record[field] = info
        return record
    else:
        return None

# %% [markdown]
# ## Run scraping

# %%
def main():
    df = pd.DataFrame(columns=columns, index=None) # Reset DF to reduce memory usage
    MAX_IDX = 0
    for i in range(0, MAX_IDX+50, 50):
        urls = get_page_urls(str(i)) # Get urls of all info pages from the main page
        if not urls is None:
            for url in urls:
                info = get_page_info(url)
                # for x in list(info.keys()):
                df.loc[len(df)] = info # Add page info to DF
                print(df)

        df.to_csv('data.csv', mode='a', header=False, index=False) # Store information after each page of urls
        df = pd.DataFrame(columns=columns, index=None) # Reset DF to reduce memory usage

    print(df)

main()
# Out:
#                                              Synonyms  \
# 0                              Frieren at the Funeral
# 1                                                 NaN
# 2   Hagane no Renkinjutsushi: Fullmetal Alchemist,...
# 3                                                 NaN
# 4                                                 NaN
# 5                                     Gintama' (2015)
# 6                                                 NaN
# 7                                      Gintama (2011)
# 8                                          HxH (2011)
# 9        Gintama' (2012), Gintama' Overdrive, Kintama
# 14       12   Finished Airing   Jan 9, 2017 to Mar 27, 2017  ['Winter 2017']
# 15       13   Finished Airing   Apr 6, 2021 to Jun 29, 2021  ['Spring 2021']
# 16       24   Finished Airing   Oct 3, 2008 to Mar 27, 2009    ['Fall 2008']
# 17      201   Finished Airing   Apr 4, 2006 to Mar 25, 2010  ['Spring 2006']
# 18        1   Finished Airing                  Sep 17, 2016              NaN
# 19       22   Finished Airing  Oct 14, 2017 to Mar 31, 2018    ['Fall 2017']
# 20       25   Finished Airing   Apr 6, 2008 to Sep 28, 2008  ['Spring 2008']
# 21        1   Finished Airing                   Jul 6, 2013              NaN
# 22       24   Finished Airing  Oct 22, 2023 to Mar 24, 2024    ['Fall 2023']
# 23       74   Finished Airing   Apr 7, 2004 to Sep 28, 2005  ['Spring 2004']
# 24       14   Finished Airing    Jul 9, 2018 to Oct 8, 2018  ['Summer 2018']
# 25        7   Finished Airing  Aug 12, 2017 to Aug 13, 2017              NaN
# 26        2   Finished Airing    Mar 4, 2023 to Nov 5, 2023              NaN
# 27        1   Finished Airing                  Sep 18, 2020              NaN
# 28       16  Currently Airing              Oct 2, 2024 to ?    ['Fall 2024']
# 29        1   Finished Airing                  Aug 26, 2016              NaN
# 30       26   Finished Airing   Apr 6, 2020 to Oct 17, 2021  ['Spring 2020']
# 31        1   Finished Airing                  Jun 28, 2024              NaN
# 32       12   Finished Airing   Jan 8, 2018 to Mar 26, 2018  ['Winter 2018']
# 33       24   Finished Airing  Jan 10, 2023 to Jun 20, 2023  ['Winter 2023']
# 34       13   Finished Airing    Jan 7, 2019 to Apr 1, 2019  ['Winter 2019']
# 35       13   Finished Airing   Jan 7, 2024 to Mar 31, 2024  ['Winter 2024']
# 36       16   Finished Airing   Dec 7, 2020 to Mar 29, 2021  ['Winter 2021']
# 37       23   Finished Airing   Jul 6, 2023 to Dec 28, 2023  ['Summer 2023']
# 38        1   Finished Airing                   Jan 6, 2017              NaN
# 39       14   Finished Airing   Jul 6, 2024 to Oct 19, 2024              NaN
# 40       12   Finished Airing   Oct 9, 2022 to Dec 25, 2022    ['Fall 2022']
# 41       10   Finished Airing   Oct 8, 2016 to Dec 10, 2016    ['Fall 2016']
# 42       75   Finished Airing   Oct 4, 2000 to Mar 27, 2002    ['Fall 2000']
# 43        1   Finished Airing                  Jul 20, 2001              NaN
# 44       12   Finished Airing   Jan 10, 2022 to Apr 4, 2022  ['Winter 2022']
# 45       24   Finished Airing   Jul 8, 2019 to Dec 30, 2019  ['Summer 2019']
# 46       26   Finished Airing   Jul 7, 2013 to Dec 29, 2013  ['Summer 2013']
# 47        1   Finished Airing                  Dec 17, 2022              NaN
# 48       26   Finished Airing   Apr 3, 1998 to Apr 24, 1999  ['Spring 1998']
# 49        1   Finished Airing                   Dec 3, 2022              NaN
#
#                     Broadcast  ...            Source  \
# 0      Fridays at 23:00 (JST)  ...         ['Manga']
# 1                         NaN  ...   ['Light novel']
# 2      Sundays at 17:00 (JST)  ...         ['Manga']
# 3   Wednesdays at 02:05 (JST)  ...      Visual novel
# 4      Mondays at 00:10 (JST)  ...         ['Manga']
# 5   Wednesdays at 18:00 (JST)  ...         ['Manga']
# 6                         NaN  ...         ['Manga']
# 7      Mondays at 18:00 (JST)  ...         ['Manga']
# 8      Sundays at 10:55 (JST)  ...         ['Manga']
# 9    Thursdays at 18:00 (JST)  ...         ['Manga']
# 10    Tuesdays at 00:00 (JST)  ...         ['Manga']
# 11                        NaN  ...             Novel
# 12   Saturdays at 23:00 (JST)  ...         ['Manga']
# 13   Saturdays at 00:00 (JST)  ...         ['Manga']
# 14     Mondays at 01:35 (JST)  ...         ['Manga']
# 15    Tuesdays at 01:30 (JST)  ...         ['Manga']
# 16     Fridays at 01:59 (JST)  ...      Visual novel
# 17   Thursdays at 18:00 (JST)  ...         ['Manga']
# 18                        NaN  ...         ['Manga']
# 19   Saturdays at 23:00 (JST)  ...         ['Manga']
# 20     Sundays at 17:00 (JST)  ...          Original
# 21                        NaN  ...         ['Manga']
# 22     Sundays at 01:05 (JST)  ...   ['Light novel']
# 23  Wednesdays at 00:40 (JST)  ...         ['Manga']
# 24     Mondays at 01:35 (JST)  ...         ['Manga']
# 25                        NaN  ...   ['Light novel']
# 26                        NaN  ...         ['Manga']
# 27                        NaN  ...   ['Light novel']
# 28  Wednesdays at 22:30 (JST)  ...   ['Light novel']
# 29                        NaN  ...          Original
# 30     Mondays at 00:10 (JST)  ...         ['Manga']
# 31                        NaN  ...         ['Manga']
# 32     Mondays at 01:35 (JST)  ...         ['Manga']
# 33    Tuesdays at 00:30 (JST)  ...         ['Manga']
# 34     Mondays at 23:00 (JST)  ...     ['Web manga']
# 35     Sundays at 01:30 (JST)  ...         ['Manga']
# 36     Mondays at 00:10 (JST)  ...         ['Manga']
# 37   Thursdays at 23:56 (JST)  ...         ['Manga']
# 38                        NaN  ...   ['Light novel']
# 39                        NaN  ...   ['Light novel']
# 40     Sundays at 00:00 (JST)  ...  ['4-koma manga']
# 41   Saturdays at 01:55 (JST)  ...         ['Manga']
# 42    Tuesdays at 00:50 (JST)  ...         ['Manga']
# 43                        NaN  ...          Original
# 44     Mondays at 00:05 (JST)  ...         ['Manga']
# 45     Mondays at 00:10 (JST)  ...         ['Manga']
# 46     Sundays at 00:00 (JST)  ...   ['Light novel']
# 47                        NaN  ...         ['Manga']
# 48   Saturdays at 01:00 (JST)  ...          Original
# 49                        NaN  ...         ['Manga']
#
#                                               Genres  Demographic  \
# 0                  ['Adventure', 'Drama', 'Fantasy']  ['Shounen']
# 1                 ['Action', 'Adventure', 'Fantasy']  ['Shounen']
# 2        ['Action', 'Adventure', 'Drama', 'Fantasy']  ['Shounen']
# 3                    ['Drama', 'Sci-Fi', 'Suspense']          NaN
# 4                    ['Action', 'Drama', 'Suspense']  ['Shounen']
# 5                     ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 6            ['Action', 'Comedy', 'Drama', 'Sci-Fi']  ['Shounen']
# 7                     ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 8                 ['Action', 'Adventure', 'Fantasy']  ['Shounen']
# 9                     ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 10           ['Action', 'Adventure', 'Supernatural']  ['Shounen']
# 11                               ['Drama', 'Sci-Fi']          NaN
# 12           ['Action', 'Adventure', 'Supernatural']  ['Shounen']
# 13                             ['Comedy', 'Romance']   ['Seinen']
# 14                    ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 15              ['Drama', 'Romance', 'Supernatural']   ['Shoujo']
# 16              ['Drama', 'Romance', 'Supernatural']          NaN
# 17                    ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 18                        ['Award Winning', 'Drama']  ['Shounen']
# 19                                               NaN   ['Seinen']
# 20    ['Action', 'Award Winning', 'Drama', 'Sci-Fi']          NaN
# 21                    ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 22                              ['Drama', 'Mystery']          NaN
# 23                  ['Drama', 'Mystery', 'Suspense']   ['Seinen']
# 24                    ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 25             ['Comedy', 'Mystery', 'Supernatural']          NaN
# 26                   ['Action', 'Drama', 'Suspense']  ['Shounen']
# 27                        ['Award Winning', 'Drama']          NaN
# 28                  ['Drama', 'Fantasy', 'Suspense']          NaN
# 29                        ['Award Winning', 'Drama']          NaN
# 30                                               NaN   ['Seinen']
# 31                                               NaN  ['Shounen']
# 32                    ['Action', 'Comedy', 'Sci-Fi']  ['Shounen']
# 33                  ['Action', 'Adventure', 'Drama']   ['Seinen']
# 34              ['Action', 'Comedy', 'Supernatural']          NaN
# 35                             ['Comedy', 'Romance']  ['Shounen']
# 36                   ['Action', 'Drama', 'Suspense']  ['Shounen']
# 37                        ['Action', 'Supernatural']  ['Shounen']
# 38             ['Action', 'Mystery', 'Supernatural']          NaN
# 39             ['Comedy', 'Mystery', 'Supernatural']          NaN
# 40                                               NaN          NaN
# 41                                               NaN  ['Shounen']
# 42                                               NaN  ['Shounen']
# 43         ['Adventure', 'Award Winning', 'Fantasy']          NaN
# 44                   ['Action', 'Drama', 'Suspense']  ['Shounen']
# 45                  ['Action', 'Adventure', 'Drama']   ['Seinen']
# 46  ['Comedy', 'Mystery', 'Romance', 'Supernatural']          NaN
# 47                    ['Comedy', 'Drama', 'Romance']   ['Seinen']
# 48             ['Action', 'Award Winning', 'Sci-Fi']          NaN
# 49                       ['Award Winning', 'Sports']  ['Shounen']
#
#                  Duration                          Rating Score Ranked  \
# 0         24 min. per ep.       PG-13 - Teens 13 or older  9.32      1
# 1                 24 min.       PG-13 - Teens 13 or older  9.14      2
# 2         24 min. per ep.  R - 17+ (violence & profanity)  9.09      3
# 3         24 min. per ep.       PG-13 - Teens 13 or older  9.07      4
# 4         23 min. per ep.  R - 17+ (violence & profanity)  9.05      5
# 5         24 min. per ep.       PG-13 - Teens 13 or older  9.05      6
# 6           1 hr. 44 min.       PG-13 - Teens 13 or older  9.04      7
# 7         24 min. per ep.       PG-13 - Teens 13 or older  9.03      8
# 8         23 min. per ep.       PG-13 - Teens 13 or older  9.03      9
# 9         24 min. per ep.       PG-13 - Teens 13 or older  9.02     10
# 10        24 min. per ep.  R - 17+ (violence & profanity)  9.01     11
# 11        26 min. per ep.  R - 17+ (violence & profanity)  9.01     12
# 12                24 min.  R - 17+ (violence & profanity)  9.00     13
# 13        23 min. per ep.       PG-13 - Teens 13 or older  8.99     14
# 14        24 min. per ep.       PG-13 - Teens 13 or older  8.98     15
# 15        23 min. per ep.       PG-13 - Teens 13 or older  8.96     16
# 29         11  2825735      91817
# 30       2041   110804       2289
# 31       2307    91217       1630
# 32       1165   219624       1188
# 33        315   683399      16317
# 34         74  1591546      32906
# 35       1127   225705       4952
# 36         33  2083319      52589
# 37        144  1087250      23479
# 38        492   478207       7732
# 39       2574    76260        717
# 40        350   639625      30671
# 41        115  1243017      15672
# 42        363   623219      23033
# 43         44  1906332      33508
# 44        102  1372095      30735
# 45         72  1603307      50232
# 46        314   685073      23752
# 47        858   300190       2048
# 48         43  1921505      84440
# 49       3089    55231        796
#
# [50 rows x 23 columns]

# %%
# get_page_urls(0)
test_url = "https://myanimelist.net/anime/52991/Sousou_no_Frieren"
get_page_info(test_url)
# Out:
# Frieren: Beyond Journey's End
# Synonyms
# Japanese
# English
# Type
# ['TV']
# Episodes
# Status
# Aired
# Premiered
# ['Fall 2023']
# Broadcast
# Producers
# ['Aniplex', 'Dentsu', 'Shogakukan-Shueisha Productions', 'Nippon Television Network', 'TOHO animation', 'Shogakukan']
# Licensors
# ['Crunchyroll']
# Studios
# ['Madhouse']
# Source
# ['Manga']
# Genres
# ['Adventure', 'Drama', 'Fantasy']
# Demographic
# ['Shounen']
# Duration
# Rating
# Score
# Ranked
# Popularity
# Members
# Favorites
# {'Synonyms': 'Frieren at the Funeral', 'Japanese': '葬送のフリーレン', 'English': "Frieren: Beyond Journey's End", 'Type': ['TV'], 'Episodes': '28', 'Status': 'Finished Airing', 'Aired': 'Sep 29, 2023 to Mar 22, 2024', 'Premiered': ['Fall 2023'], 'Broadcast': 'Fridays at 23:00 (JST)', 'Producers': ['Aniplex', 'Dentsu', 'Shogakukan-Shueisha Productions', 'Nippon Television Network', 'TOHO animation', 'Shogakukan'], 'Licensors': ['Crunchyroll'], 'Studios': ['Madhouse'], 'Source': ['Manga'], 'Genres': ['Adventure', 'Drama', 'Fantasy'], 'Demographic': ['Shounen'], 'Duration': '24 min. per ep.', 'Rating': 'PG-13 - Teens 13 or older', 'Score': '9.32', 'Ranked': '1', 'Popularity': '185', 'Members': '946246', 'Favorites': '56511', 'Title': 'Sousou no Frieren'}
# {'Synonyms': 'Frieren at the Funeral',
#  'Japanese': '葬送のフリーレン',
#  'English': "Frieren: Beyond Journey's End",
#  'Type': ['TV'],
#  'Episodes': '28',
#  'Status': 'Finished Airing',
#  'Aired': 'Sep 29, 2023 to Mar 22, 2024',
#  'Premiered': ['Fall 2023'],
#  'Broadcast': 'Fridays at 23:00 (JST)',
#  'Producers': ['Aniplex',
#   'Dentsu',
#   'Shogakukan-Shueisha Productions',
#   'Nippon Television Network',
#   'TOHO animation',
#   'Shogakukan'],
#  'Licensors': ['Crunchyroll'],
#  'Studios': ['Madhouse'],
#  'Source': ['Manga'],
#  'Genres': ['Adventure', 'Drama', 'Fantasy'],
#  'Demographic': ['Shounen'],
#  'Duration': '24 min. per ep.',
#  'Rating': 'PG-13 - Teens 13 or older',
#  'Score': '9.32',
#  'Ranked': '1',
#  'Popularity': '185',
#  'Members': '946246',
#  'Favorites': '56511',
#  'Title': 'Sousou no Frieren'}
